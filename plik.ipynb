# %%
# Klasyfikator opinii

from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import GaussianNB, MultinomialNB, BernoulliNB
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score
import pandas as pd

def przetestuj_nowe_zdanie(model, vectorizer, nowe_zdanie):
    zdanie_vectorized = vectorizer.transform([nowe_zdanie])
    
    przewidywana_klasa = model.predict(zdanie_vectorized)
    print(f"'{model}' uważa, że '{nowe_zdanie}' to {przewidywana_klasa[0]}")

data = {
    'message': [
        "Świetny produkt! Zdecydowanie przewyższył moje oczekiwania, działa dokładnie tak, jak opisano.", 
        "Używam go od kilku miesięcy i nie mam żadnych zastrzeżeń. Doskonała jakość za tę cenę!", 
        "Bardzo szybka dostawa, produkt idealnie zapakowany. Działa bez zarzutu. Polecam!",
        "Nie spodziewałem się aż tak dobrego wykonania. Solidny, trwały i wygląda elegancko.",
        "Idealny dla osób, które cenią sobie prostotę i funkcjonalność. Jestem bardzo zadowolona.",
        "Obsługa klienta na najwyższym poziomie, a produkt spełnia wszystkie moje oczekiwania.",
        "Naprawdę polecam! Jestem zachwycony, a moi znajomi już zamówili ten sam model.",
        "Przekonałem się, że warto inwestować w jakość. Ten produkt to strzał w dziesiątkę!",
        "Fantastyczny design i świetne funkcje. Cieszę się, że wybrałem właśnie ten model.",
        "Bezproblemowe użytkowanie, działa cicho i wydajnie. Idealne do codziennego użytku.",
        "Fantastyczna jakość, produkt idealnie spełnia swoje zadanie!",
        "Jestem zachwycony – wygląda świetnie, działa perfekcyjnie.",
        "Dokładnie tego potrzebowałem, świetny stosunek jakości do ceny.",
        "Produkt zgodny z opisem, działa bez zarzutu, polecam!",
        "Bardzo prosty w obsłudze, idealny dla początkujących.",
        "Solidne wykonanie, czuć, że to produkt premium.",
        "Świetna obsługa klienta, a produkt przekroczył moje oczekiwania.",
        "Dostawa ekspresowa, a sam produkt działa idealnie od pierwszego użycia.",
        "Lekki, poręczny, a jednocześnie bardzo wytrzymały. Polecam!",
        "To moje najlepsze zakupy w tym roku, jestem bardzo zadowolona.",
        "Nie zamieniłbym go na żaden inny model – jest idealny!",
        "Pracuje bardzo cicho, idealny do mojego domu.",
        "Uwielbiam design – elegancki i nowoczesny, pasuje do każdego wnętrza.",
        "Sprawdził się zarówno u mnie, jak i wśród znajomych. Warto kupić!",
        "Łatwy w montażu, działa tak, jak opisano. Bez zastrzeżeń!",
        "Najlepszy produkt w tej kategorii, jaki do tej pory używałem.",
        "Przydatne funkcje, o których nawet nie wiedziałem, że ich potrzebuję!",
        "Idealny na prezent, obdarowana osoba była zachwycona.",
        "Rewelacyjny w podróży – kompaktowy, a jednocześnie bardzo funkcjonalny.",
        "Polecam każdemu, kto się waha. To naprawdę świetny wybór!",        
        "Produkt rozpadł się po kilku dniach użytkowania. Nie polecam nikomu.",
        "Nie działa tak, jak w opisie. Strata pieniędzy, a obsługa klienta nie pomogła.",
        "Kiepska jakość wykonania. Wygląda tanio i jest bardzo delikatny.",
        "Zamówiłem, ale dostałem coś zupełnie innego. Kompletne rozczarowanie.",
        "Działał dobrze przez tydzień, potem zaczęły się problemy. Bardzo zawiedziony.",
        "Nie warte swojej ceny. Są lepsze produkty w tym przedziale cenowym.",
        "Instrukcja obsługi jest nieczytelna, a sam produkt jest skomplikowany w użyciu.",
        "Zapach plastiku był tak intensywny, że musiałem go wyrzucić. Bardzo słaby produkt.",
        "Reklamacje nie uznano, choć produkt był wyraźnie wadliwy. Brak szacunku dla klienta.",
        "Miał być nowy, a wyglądał jak używany. Nigdy więcej zakupów od tego producenta.",
        "Produkt dotarł uszkodzony, a reklamacja trwała wieki. Bardzo rozczarowany.",
        "Nie działał od pierwszego dnia. Całkowita strata pieniędzy.",
        "Wygląda ładnie, ale jakość pozostawia wiele do życzenia.",
        "Za taką cenę spodziewałem się znacznie lepszego wykonania.",
        "Opis produktu jest mylący – w rzeczywistości wygląda zupełnie inaczej.",
        "Produkt jest głośny i niewygodny w użytkowaniu. Nie polecam.",
        "Zepsuł się po dwóch tygodniach. Odradzam zakup.",
        "Słaba jakość materiałów, widać oszczędności na każdym kroku.",
        "Nie pasuje do opisu, musiałem zwrócić. Strata czasu.",
        "Instrukcja to jakiś żart – nie da się tego używać bez frustracji.",
        "Zdecydowanie nie wart swojej ceny, są lepsze opcje na rynku.",
        "Produkt wyglądał na solidny, ale okazał się zupełnie nietrwały.",
        "Nie spełnia podstawowych funkcji, które producent obiecuje.",
        "Działa wolno i ma mnóstwo błędów – bardzo irytujące.",
        "Obsługa klienta nie pomogła rozwiązać problemu. Bardzo słaby serwis.",
        "Zawiodłem się na marce, myślałem, że będzie lepiej.",
        "Zbyt skomplikowany w obsłudze, nie polecam starszym osobom.",
        "Nie polecam, produkt ma więcej wad niż zalet.",
        "Zewnętrzny wygląd OK, ale w środku tandeta.",
        "Kiepsko zapakowany, dotarł z widocznymi uszkodzeniami."
    ],
    'label': [
        "Pozytywne", "Pozytywne", "Pozytywne", "Pozytywne", "Pozytywne", "Pozytywne", "Pozytywne", "Pozytywne", "Pozytywne", "Pozytywne", "Pozytywne", "Pozytywne", "Pozytywne", "Pozytywne", "Pozytywne", "Pozytywne", "Pozytywne", "Pozytywne", "Pozytywne", "Pozytywne", "Pozytywne", "Pozytywne", "Pozytywne", "Pozytywne", "Pozytywne", "Pozytywne", "Pozytywne", "Pozytywne", "Pozytywne", "Pozytywne",
        "Negatywne", "Negatywne", "Negatywne", "Negatywne", "Negatywne", "Negatywne", "Negatywne", "Negatywne", "Negatywne", "Negatywne", "Negatywne", "Negatywne", "Negatywne", "Negatywne", "Negatywne", "Negatywne", "Negatywne", "Negatywne", "Negatywne", "Negatywne", "Negatywne", "Negatywne", "Negatywne", "Negatywne", "Negatywne", "Negatywne", "Negatywne", "Negatywne", "Negatywne", "Negatywne"
    ]
}

df = pd.DataFrame(data)

X = df['message']
y = df['label']

# Multinomial
vectorizer = CountVectorizer()
X_vectorized = vectorizer.fit_transform(X).toarray()

X_train, X_test, y_train, y_test = train_test_split(X_vectorized, y, test_size=0.3, random_state=42)

models = {
    'Gaussian Naive Bayes': GaussianNB(),
    'Multinomial Naive Bayes': MultinomialNB(),
    'Bernoulli Naive Bayes': BernoulliNB()
}

for model_name, model in models.items():
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    
    accuracy = accuracy_score(y_test, y_pred)
    print(f"{model_name} - Dokładność: {accuracy:.2f}")

print("")

nowe_zdanie1 = "Produkt jest w porządku, ale spodziewałem się lepszego wykonania w tej cenie."
nowe_zdanie2 = "Używam go codziennie i jak dotąd nie zauważyłem żadnych problemów. Warto było kupić."
nowe_zdanie3 = "Niestety, już po kilku użyciach pojawiły się uszkodzenia. Nie polecam."
nowe_zdanie4 = "Wygląda świetnie, działa jeszcze lepiej! Zdecydowanie kupiłbym ponownie."
nowe_zdanie5 = "Instrukcja obsługi jest niejasna, a sam produkt skomplikowany i mało intuicyjny."
nowe_zdanie6 = "Szybka wysyłka, świetnie zapakowane, a sam produkt spełnia wszystkie moje oczekiwania."
nowe_zdanie7 = "Zamówiłem na próbę i jestem bardzo pozytywnie zaskoczony – jakość zdecydowanie na plus."

przetestuj_nowe_zdanie(model=models['Multinomial Naive Bayes'], vectorizer=vectorizer, nowe_zdanie=nowe_zdanie1)
przetestuj_nowe_zdanie(model=models['Multinomial Naive Bayes'], vectorizer=vectorizer, nowe_zdanie=nowe_zdanie2)
przetestuj_nowe_zdanie(model=models['Multinomial Naive Bayes'], vectorizer=vectorizer, nowe_zdanie=nowe_zdanie3)
przetestuj_nowe_zdanie(model=models['Multinomial Naive Bayes'], vectorizer=vectorizer, nowe_zdanie=nowe_zdanie4)
przetestuj_nowe_zdanie(model=models['Multinomial Naive Bayes'], vectorizer=vectorizer, nowe_zdanie=nowe_zdanie5)
przetestuj_nowe_zdanie(model=models['Multinomial Naive Bayes'], vectorizer=vectorizer, nowe_zdanie=nowe_zdanie6)
przetestuj_nowe_zdanie(model=models['Multinomial Naive Bayes'], vectorizer=vectorizer, nowe_zdanie=nowe_zdanie7)
print("")

# Bernoulli
vectorizer = CountVectorizer(binary=True)
X_vectorized = vectorizer.fit_transform(X).toarray()

X_train, X_test, y_train, y_test = train_test_split(X_vectorized, y, test_size=0.3, random_state=42)

przetestuj_nowe_zdanie(model=models['Bernoulli Naive Bayes'], vectorizer=vectorizer, nowe_zdanie=nowe_zdanie1)
przetestuj_nowe_zdanie(model=models['Bernoulli Naive Bayes'], vectorizer=vectorizer, nowe_zdanie=nowe_zdanie2)
przetestuj_nowe_zdanie(model=models['Bernoulli Naive Bayes'], vectorizer=vectorizer, nowe_zdanie=nowe_zdanie3)
przetestuj_nowe_zdanie(model=models['Bernoulli Naive Bayes'], vectorizer=vectorizer, nowe_zdanie=nowe_zdanie4)
przetestuj_nowe_zdanie(model=models['Bernoulli Naive Bayes'], vectorizer=vectorizer, nowe_zdanie=nowe_zdanie5)
przetestuj_nowe_zdanie(model=models['Bernoulli Naive Bayes'], vectorizer=vectorizer, nowe_zdanie=nowe_zdanie6)
przetestuj_nowe_zdanie(model=models['Bernoulli Naive Bayes'], vectorizer=vectorizer, nowe_zdanie=nowe_zdanie7)
print("")

# Gauss
vectorizer = TfidfVectorizer()
X_vectorized = vectorizer.fit_transform(X).toarray()

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X_vectorized)

X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.3, random_state=42)

gnb_model = GaussianNB()
gnb_model.fit(X_train, y_train)

y_pred = gnb_model.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)

def przetestuj_nowe_zdanie_gauss(model, vectorizer, scaler, nowe_zdanie):
    zdanie_vectorized = vectorizer.transform([nowe_zdanie]).toarray()
    zdanie_scaled = scaler.transform(zdanie_vectorized) 
    
    przewidywana_klasa = model.predict(zdanie_scaled)
    print(f"'{model}' uważa, że '{nowe_zdanie}' to {przewidywana_klasa[0]}")

przetestuj_nowe_zdanie_gauss(model=models['Gaussian Naive Bayes'], vectorizer=vectorizer, scaler=scaler, nowe_zdanie=nowe_zdanie1)
przetestuj_nowe_zdanie_gauss(model=models['Gaussian Naive Bayes'], vectorizer=vectorizer, scaler=scaler, nowe_zdanie=nowe_zdanie2)
przetestuj_nowe_zdanie_gauss(model=models['Gaussian Naive Bayes'], vectorizer=vectorizer, scaler=scaler, nowe_zdanie=nowe_zdanie3)
przetestuj_nowe_zdanie_gauss(model=models['Gaussian Naive Bayes'], vectorizer=vectorizer, scaler=scaler, nowe_zdanie=nowe_zdanie4)
przetestuj_nowe_zdanie_gauss(model=models['Gaussian Naive Bayes'], vectorizer=vectorizer, scaler=scaler, nowe_zdanie=nowe_zdanie5)
przetestuj_nowe_zdanie_gauss(model=models['Gaussian Naive Bayes'], vectorizer=vectorizer, scaler=scaler, nowe_zdanie=nowe_zdanie6)
przetestuj_nowe_zdanie_gauss(model=models['Gaussian Naive Bayes'], vectorizer=vectorizer, scaler=scaler, nowe_zdanie=nowe_zdanie7)
# Out:
# Gaussian Naive Bayes - Dokładność: 0.72
# Multinomial Naive Bayes - Dokładność: 0.83
# Bernoulli Naive Bayes - Dokładność: 0.67
#
# 'MultinomialNB()' uważa, że 'Produkt jest w porządku, ale spodziewałem się lepszego wykonania w tej cenie.' to Negatywne
# 'MultinomialNB()' uważa, że 'Używam go codziennie i jak dotąd nie zauważyłem żadnych problemów. Warto było kupić.' to Pozytywne
# 'MultinomialNB()' uważa, że 'Niestety, już po kilku użyciach pojawiły się uszkodzenia. Nie polecam.' to Negatywne
# 'MultinomialNB()' uważa, że 'Wygląda świetnie, działa jeszcze lepiej! Zdecydowanie kupiłbym ponownie.' to Pozytywne
# 'MultinomialNB()' uważa, że 'Instrukcja obsługi jest niejasna, a sam produkt skomplikowany i mało intuicyjny.' to Negatywne
# 'MultinomialNB()' uważa, że 'Szybka wysyłka, świetnie zapakowane, a sam produkt spełnia wszystkie moje oczekiwania.' to Pozytywne
# ...
